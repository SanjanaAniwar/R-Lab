# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjanaAniwar/R-Lab/blob/main/R_Mini_Project_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data<- read.csv("http://archive.ics.uci.edu/ml/machine-learning-databases/00537/sobar-72.csv")
data
# Out:
#    behavior_sexualRisk behavior_eating behavior_personalHygine
# 1  10                  13              12
# 2  10                  11              11
# 3  10                  15               3
# 4  10                  11              10
# 5   8                  11               7
# 6  10                  14               8
# 7  10                  15               4
# 8   8                  12               9
# 9  10                  15               7
# 10  7                  15               7
# 11  7                  15               7
# 12 10                  15               8
# 13 10                  15              12
# 14  9                  12              14
# 15  2                  15              15
# 16 10                  15               7
# 17 10                  15               9
# 18 10                  12               7
# 19 10                  11              12
# 20 10                  12              12
# 21 10                  15              15
# ...

# %%
# a.find out how many values are missing in each of the columns of data set
tar <- data$target
sapply(data, function(tar) sum(is.na(tar)))
# Out:
#        behavior_sexualRisk            behavior_eating
#                          0                          0
#    behavior_personalHygine      intention_aggregation
#                          0                          0
#       intention_commitment       attitude_consistency
#                          0                          0
#       attitude_spontaneity     norm_significantPerson
#                          0                          0
#           norm_fulfillment   perception_vulnerability
#                          0                          0
#        perception_severity        motivation_strength
#                          0                          0
#     motivation_willingness socialSupport_emotionality
#                          0                          0
# socialSupport_appreciation socialSupport_instrumental
#                          0                          0
#      empowerment_knowledge      empowerment_abilities
# ...

# %%
# b. select column with more than 10% values missing for deletion. new copy has one less column called sample_data_1less
sample_data_1less <-data[, which(colMeans(!is.na(data)) > 0.1)]
summary(sample_data_1less)
# Out:
#  behavior_sexualRisk behavior_eating behavior_personalHygine
#  Min.   : 2.000      Min.   : 3.00   Min.   : 3.00
#  1st Qu.:10.000      1st Qu.:11.00   1st Qu.: 9.00
#  Median :10.000      Median :13.00   Median :11.00
#  Mean   : 9.667      Mean   :12.79   Mean   :11.08
#  3rd Qu.:10.000      3rd Qu.:15.00   3rd Qu.:14.00
#  Max.   :10.000      Max.   :15.00   Max.   :15.00
#  intention_aggregation intention_commitment attitude_consistency
#  Min.   : 2.000        Min.   : 6.00        Min.   : 2.000
#  1st Qu.: 6.000        1st Qu.:11.00        1st Qu.: 6.000
#  Median :10.000        Median :15.00        Median : 7.000
#  Mean   : 7.903        Mean   :13.35        Mean   : 7.181
#  3rd Qu.:10.000        3rd Qu.:15.00        3rd Qu.: 8.000
#  Max.   :10.000        Max.   :15.00        Max.   :10.000
#  attitude_spontaneity norm_significantPerson norm_fulfillment
#  Min.   : 4.000       Min.   :1.000          Min.   : 3.000
# ...

# %%
# c. Find 5 point summary of all remaining columns with numric attributes
fivenum(data$behavior_eating)
fivenum(data$behavior_personalHygine)
fivenum(data$intention_aggregation)
fivenum(data$intention_commitment)
# Out:
# [1]  3 11 13 15 15
# [1]  3  9 11 14 15
# [1]  2  6 10 10 10
# [1]  6 11 15 15 15

# %%
# d. For attribute having maximum spread delete all tuples that have value less than the mean of the attribute selected. Count the number of tuples reamining in the sampled dataset.

m <- mean(data$trestbps, na.rm = FALSE)
m

df2 <- subset(data, data$trestbps< m)
summary(df2$trestbps)
print('Rows before row deletion: ')
nrow(data)
print('Rows before row deletion: ')
nrow(df2)
# Out:
# Warning message in mean.default(data$trestbps, na.rm = FALSE):
# “argument is not numeric or logical: returning NA”
# [1] NA
# Length  Class   Mode
#      0   NULL   NULL
# [1] "Rows before row deletion: "
# [1] 72
# [1] "Rows before row deletion: "
# [1] 0
